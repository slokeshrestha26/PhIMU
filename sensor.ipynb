# %%
import matplotlib.pyplot as plt
import librosa

# %%
sr = 8000
mp4 = librosa.load('Microphone.mp4', sr=None, mono=True)
print(mp4[0][-10:])
# Out:
# [-0.00048828 -0.00048828 -0.00048828 -0.00048828 -0.00048828 -0.00048828
#  -0.00048828 -0.00024414  0.         -0.00024414]

# %%
plt.plot(mp4[0])
